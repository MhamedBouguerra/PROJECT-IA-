# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
dataml=pd.read_csv('ML.csv')
dataml=dataml.drop(['Unnamed: 0'],axis=1)

# %%
dataml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29254 entries, 0 to 29253
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   codeCompagnie                  29254 non-null  int64
#  1   NbrSinistre                    29254 non-null  int64
#  2   typeIntermediaire              29254 non-null  int64
#  3   VolontaireAccidents            29254 non-null  float64
#  4   CountSinisterAdvr              29254 non-null  int64
#  5   naturePolice                   29254 non-null  int64
#  6   Etat_Police                    29254 non-null  int64
#  7   vehicule_id                    29254 non-null  int64
#  8   assure_id                      29254 non-null  int64
#  9   classeBonusMalus               29254 non-null  int64
#  10  CONTRAT_EN_COURS               29254 non-null  int64
#  11  puissanceFiscal                29254 non-null  int64
# ...

# %%
X=dataml.drop(columns=["jour_dateEcheancePolice","mois_dateEcheancePolice","VolontaireAccidents","CountSinisterAdvr","typeIntermediaire","vehicule_id","assure_id","CONTRAT_EN_COURS","pourcentadeDeResponsabilite","porcentageCompagnieAdverse","Duree","Fraud"])
Y=dataml['Fraud']

# %%
X
# Out:
#        codeCompagnie  NbrSinistre  naturePolice  Etat_Police  \
# 0                  1            1             0            2
# 1                  1            1             0            2
# 2                  1            1             0            0
# 3                  1            1             0            0
# 4                  1            1             0            0
# ...              ...          ...           ...          ...
# 29249              1            1             0            2
# 29250              1            1             0            2
# 29251              1            1             0            0
# 29252              1            1             0            0
# 29253              1            1             0            2
#
#        classeBonusMalus  puissanceFiscal  energie  etatVehicule  libUsage  \
# 0                     1                7        3             1         7
# 1                     3                4        3             1         9
# ...
